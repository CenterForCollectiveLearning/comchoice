# %%
from comchoice.analyzer import create_random_spread,plot_states,spatial_aggregate_grids

# %%
states = create_random_spread(number_grids=20, speed=0.1)

# %%
print("You can use the function 'plot_states' to plot any evolution of elections or spread of diseases or anything represented in a dictionary of matrices in 2D")
plot_states(states, nrows=2)
# Out:
# You can use the function 'plot_states' to plot any evolution of elections or spread of diseases or anything represented in a dictionary of matrices in 2D

# %%
newstate = spatial_aggregate_grids(states[5], new_size=5)
# Out:
# 20 5 4 (5, 5)
